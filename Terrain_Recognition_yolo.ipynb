# %%
from ultralytics import YOLO

# %%
import numpy as np

# %%
# Load a model
model = YOLO('yolov8n-cls.yaml')  # build a new model from YAML
model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n-cls.yaml').load('yolov8n-cls.pt')  # build from YAML and transfer weights

# Train the model
results = model.train(data=r'E:\SIH_2023\gmapsdatasetsss', epochs=100, imgsz=64)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1   # top1 accuracy
metrics.top5
# Out:
# Ultralytics YOLOv8.0.143  Python-3.9.7 torch-2.0.1+cpu CPU (AMD Ryzen 7 3700X 8-Core Processor)
# YOLOv8n-cls summary (fused): 73 layers, 1442566 parameters, 0 gradients, 3.3 GFLOPs
# WARNING  Dataset 'split=val' not found, using 'split=test' instead.
#                classes   top1_acc   top5_acc: 100%|██████████| 32/32 [00:04<00:00,  6.76it/s]
#                    all      0.806      0.996
# Speed: 0.0ms preprocess, 1.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs\classify\val10
# 0.9960707426071167

# %%
results1 = model(source=r'E:\SIH_2023\Test_images\Test-15.jpg')
# Out:
# image 1/1 E:\SIH_2023\Test_images\Test-15.jpg: 64x64 Snow rocky 0.61, Water marsh 0.30, Salt marsh 0.08, Sandy 0.01, Rocky 0.01, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 64, 64)

# %%
prob1=results1[0].probs
print(prob1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11924/2890976848.py in <module>
# ----> 1 prob1=results1[0].probs
#       2 print(prob1)
#
# NameError: name 'results1' is not defined

# %%
class_mapping = {0: 'GRASS', 1: 'ROCKY', 2: 'SALT MARSH', 3: 'SANDY',4:'SNOWROCKY',5:'WATERMARSH'}
terrain = prob1.top5[0]
terrain_label = class_mapping[terrain]
print(terrain_label)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17512/1970065265.py in <module>
#       1 class_mapping = {0: 'GRASS', 1: 'MARSHY', 2: 'ROCKY', 3: 'SANDY'}
#       2 terrain = prob1.top5[0]
# ----> 3 terrain_label = class_mapping[terrain]
#       4 print(terrain_label)
#
# KeyError: 4
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
